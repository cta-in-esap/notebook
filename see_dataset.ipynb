# %%
from ctapipe.io import read_table

# %%
hdf_file = "/Users/nalvarez/Downloads/gamma_public_merged.dl2.h5"

# %%
from ctapipe.io import TableLoader

# %%
loader = TableLoader(hdf_file)

# %%
loader

# %%
events_subarray = loader.read_subarray_events()

# %%
events_subarray

# %%
#events_telescope = loader.read_telescope_events()

# %%
#events_telescope

# %%
#events_telescope_type = loader.read_telescope_events_by_type

# %%
#events_telescope_type

# %%
loader.subarray

# %%
import pandas as pd

# %%
big = pd.read_hdf(hdf_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 big = pd.read_hdf(hdf_file)
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/io/pytables.py:425, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     423 groups = store.groups()
#     424 if len(groups) == 0:
# --> 425     raise ValueError(
#     426         "Dataset(s) incompatible with Pandas data types, "
#     427         "not table, or no datasets found in HDF5 file."
#     428     )
#     429 candidate_only_group = groups[0]
#     431 # For the HDF file to have only one dataset, all other groups
#     432 # should then be metadata groups for that candidate group. (This
#     433 # assumes that the groups() method enumerates parent groups
#     434 # before their children.)
#
# ...

# %%
import tables

# %%
h5file = tables.open_file(hdf_file, mode="r", title="DL1 file")

# %%
h5file
# Out:
# File(filename=/Users/nalvarez/Downloads/gamma_public_merged.dl2.h5, title='', mode='r', root_uep='/', filters=Filters(complevel=0, shuffle=False, bitshuffle=False, fletcher32=False, least_significant_digit=None))
# / (RootGroup) ''
# /configuration (Group) ''
# /dl1 (Group) ''
# /dl2 (Group) ''
# /simulation (Group) ''
# /simulation/event (Group) ''
# /simulation/service (Group) ''
# /simulation/service/shower_distribution (Table(2150,)fletcher32, shuffle, blosc:zstd(5)) 'Storage of SimulatedShowerDistribution'
#   description := {
#   "obs_id": Int32Col(shape=(), dflt=0, pos=0),
#   "hist_id": Int64Col(shape=(), dflt=0, pos=1),
#   "n_entries": Int64Col(shape=(), dflt=0, pos=2),
#   "bins_energy": Float64Col(shape=(121,), dflt=0.0, pos=3),
#   "bins_core_dist": Float64Col(shape=(201,), dflt=0.0, pos=4),
#   "histogram": Float32Col(shape=(120, 200), dflt=0.0, pos=5)}
#   byteorder := 'little'
#   chunkshape := (2,)
# /simulation/event/subarray (Group) ''
# ...
